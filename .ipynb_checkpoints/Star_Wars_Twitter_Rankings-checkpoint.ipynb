# %%
import tweepy as tw
import csv
import numpy as np
import re
from IPython.display import display
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
consumer_key= 'xxxx'
consumer_secret= 'xxxx'
access_token= 'xxxx'
access_token_secret= 'xxxx'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
search_words = "Revenge of the Sith attack of the clones -filter:retweets"
date_since = "2019-12-19"

# %%
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en", tweet_mode="extended",
              since=date_since).items(2000)

# %%
class TweetAnalyzer():
    #Functionality for analyzing and categorizing content from tweets.
    def tweets_to_data_frame(self, tweets):
        df = pd.DataFrame(data=[tweet.full_text for tweet in tweets], columns =['Tweets'])
        return df

# %%
tweet_analyzer = TweetAnalyzer()
df = tweet_analyzer.tweets_to_data_frame(tweets)

# %%
df = pd.read_csv('star_wars_rankings1.csv', names = ['Tweets', 'Dates', 'Location'])

# %%
df.head()
# Out:
#                                               Tweets                Dates  \
# 0  @ambxrIynn Lol no worries, u should still watc...  2020-01-08 05:41:09
# 1  @Uhbolish @indyJIG Empire Strikes Back\r\nRogu...  2020-01-08 05:37:45
# 2  @ambxrIynn Tbh thats not bad, just keep in min...  2020-01-08 05:34:04
# 3  #StarWars  films rankings \r\nEmpire Strikes B...  2020-01-08 05:26:23
# 4  This right here. This is what I'm talking abou...  2020-01-08 05:25:22
#
#          Location
# 0             NaN
# 1  Liberty/Albany
# 2             NaN
# 3   Manhattan, NY
# 4   Obviously, NJ

# %%
df = df.drop(['Dates','Location'], 1)

# %%
len(df['Tweets'])
print(df.head())
# Out:
#                                               Tweets
# 0  @ambxrIynn Lol no worries, u should still watc...
# 1  @Uhbolish @indyJIG Empire Strikes Back\r\nRogu...
# 2  @ambxrIynn Tbh thats not bad, just keep in min...
# 3  #StarWars  films rankings \r\nEmpire Strikes B...
# 4  This right here. This is what I'm talking abou...

# %%
list=[]
for i in range(len(df['Tweets'])):
    sw = (df['Tweets'][i])
    sw1 = re.findall('[0-9]\.\s?(\D.+)', sw)
    sw2 = [x.strip(' ') for x in sw1]
    list.append(sw2)

# %%
pd.set_option('display.max_rows', None)
sw_df1 =  pd.DataFrame(list, columns = ['1st', '2nd', '3rd', '4th', '5th', '6th', '7th', '8th', '9th', '10th', '11th', '12th', '13th','14th', '15th'])

# %%
columns = ['12th', '13th','14th', '15th']
sw_df1.drop(columns, inplace=True, axis=1)

# %%
sw_df1.fillna(value=pd.np.nan, inplace=True)

# %%
sw_df1.dropna(subset=['1st','2nd', '3rd', '4th', '5th', '6th'], inplace=True)

# %%
sw_df1 = sw_df1.fillna(value={"7th":"Missing", "8th":"Missing","9th":"Missing","10th":"Missing","11th":"Missing",})

# %%
sw_df1.replace('(.+?)?(([Pp][Hh]\D+[Ee]?[\\r]$)|TPM|PM)', 'The Phantom Menace', regex=True, inplace=True)
sw_df1.replace('(.+?)?(([Aa][Tt]\D+[Ss]?[\\r]$)|AOTC|AOC|TAOTC|TAOC)', 'Attack of the Clones', regex=True, inplace=True)
sw_df1.replace('(.+?)?(([Rr][Ee]\D+[Hh]?[\\r]$)|ROTS|ROS|TROS|TROTS)', 'Revenge of the Sith', regex=True, inplace=True)
sw_df1.replace('(.+?)?(([Nn][Ee]\D+[Ee]?[\\r]$)|ANH|NH)', 'A New Hope', regex=True, inplace=True)
sw_df1.replace('(.+?)?(([Ee][Mm]\D+[Kk]?[\\r]$)|Empire|TESB|ESB)', 'The Empire Strikes Back', regex=True, inplace=True)
sw_df1.replace('(.+?)?(([Rr][Ee]\D+[Ii]?[\\r]$)|ROTJ|TROTJ|RotJ|ROJ)', 'Return of the Jedi', regex=True, inplace=True)
sw_df1.replace('(.+?)?(([Ff][Oo]\D+[Ss]?[\\r]$)|TFS|FS)', 'The Force Awakens', regex=True, inplace=True)
sw_df1.replace('(.+?)?(([Ll][Aa]\D+[Ii]?[\\r]$)|TLJ|LJ)', 'The Last Jedi', regex=True, inplace=True)
sw_df1.replace('(.+?)?(([Rr][Ii]\D+[Rr|*]?[\\r]$)|TROS|ROS)', 'The Rise of Skywalker', regex=True, inplace=True)
sw_df1.replace('(.+?)?(([Rr][Oo]\D+[Ee]?[\\r]$)|RO|TRO)', 'Rogue One', regex=True, inplace=True)
sw_df1.replace('(.+?)?([Ss][Oo]\D+[Oo]?[\\r]$)', 'Solo', regex=True, inplace=True)

# %%
display(sw_df1.head())
# Out:
#                     1st                   2nd                    3rd  \
# 5   Revenge of the Sith            A New Hope    Revenge of the Sith
# 7   Revenge of the Sith  Attack of the Clones    Revenge of the Sith
# 9             Rogue One         The Last Jedi   Attack of the Clones
# 16           A New Hope   Revenge of the Sith  The Rise of Skywalker
# 18  Revenge of the Sith   Revenge of the Sith      The Force Awakens
#
#                       4th                    5th                  6th  \
# 5       The Force Awakens  The Rise of Skywalker  Revenge of the Sith
# 7   The Rise of Skywalker             A New Hope    The Force Awakens
# 9     Revenge of the Sith      The Force Awakens   The Phantom Menace
# 16      The Force Awakens    Revenge of the Sith        The Last Jedi
# 18              Rogue One  The Rise of Skywalker        The Last Jedi
#
#                     7th                   8th                   9th  \
# 5    The Phantom Menace         The Last Jedi  Attack Of The Clones
# 7         The Last Jedi             Rogue One                  Solo
# 9   Revenge of the Sith            A New Hope   Revenge of the Sith
# 16  Revenge of the Sith  Attack of the Clones    The Phantom Menace
# 18           A New Hope   Revenge of the Sith  Attack of the Clones
#
#                   10th     11th
# 5              Missing  Missing
# 7   The Phantom Menace  Missing
# 9            Rogue One     Solo
# 16             Missing  Missing
# 18  The Phantom Menace     Solo

# %%
def sw_count(sw_column):
    final_count_list = []
    tpm_count = 0
    aotc_count = 0
    rots_count = 0
    anh_count = 0
    tesb_count = 0
    rotj_count = 0
    tfa_count = 0
    tlj_count = 0
    ros_count = 0
    ro_count = 0
    s_count = 0
    for x in sw_column:
        if x == 'The Phantom Menace':
            tpm_count += 1
        elif x == 'Attack of the Clones':
            aotc_count += 1
        elif x == 'Revenge of the Sith':
            rots_count += 1
        elif x == 'A New Hope':
            anh_count += 1
        elif x == 'The Empire Strikes Back':
            tesb_count += 1 
        elif x == 'Return of the Jedi':
            rotj_count += 1
        elif x == 'The Force Awakens':
            tfa_count += 1
        elif x == 'The Last Jedi':
            tlj_count += 1
        elif x == 'The Rise of Skywalker':
            ros_count += 1
        elif x == 'Rogue One':
            ro_count += 1
        elif x == 'Solo':
            s_count += 1
        else:
            pass
    final_count_list.extend([tpm_count, aotc_count, rots_count, anh_count,tesb_count, rotj_count, tfa_count, tlj_count, ros_count, ro_count, s_count])
    return final_count_list

# %%
def series_to_list(column_name):
    series = sw_df1[column_name]
    list1 = series.tolist()
    return list1

# %%
for column in sw_df1:
    columm = str(column)
    sw_list = series_to_list(columm)
    total = sw_count(sw_list)
    print(total)
# Out:
# [12, 9, 276, 41, 31, 0, 8, 15, 9, 17, 3]
# [13, 18, 178, 124, 5, 0, 13, 29, 17, 27, 2]
# [9, 7, 204, 79, 2, 0, 27, 31, 28, 38, 6]
# [19, 11, 165, 67, 1, 1, 45, 17, 40, 56, 11]
# [31, 26, 115, 54, 0, 0, 62, 25, 57, 48, 14]
# [46, 40, 111, 26, 0, 1, 77, 37, 54, 16, 22]
# [54, 32, 72, 25, 0, 0, 81, 41, 49, 26, 40]
# [50, 68, 53, 11, 0, 0, 51, 59, 48, 21, 52]
# [61, 77, 32, 7, 0, 0, 24, 50, 46, 8, 60]
# [67, 63, 19, 8, 1, 2, 18, 32, 27, 8, 36]
# [31, 59, 4, 5, 0, 0, 2, 30, 10, 2, 28]

# %%
categories = ['The Phantom Menace', 'Attack of the Clones', 'Revenge of the Sith', 'A New Hope', 'The Empire Strikes Back', 'Return of the Jedi', 'The Force Awakens', 'The Last Jedi', 'The Rise of Skywalker', 'Rogue One', 'Solo']
data1 = [13, 8, 62, 40, 213, 28, 7, 17, 7, 20, 2]
data2 = [13, 16, 40, 120, 97, 50, 13, 30, 15, 28, 2]
data3 = [8, 8, 59, 72, 40, 103, 26, 32, 27, 43, 6]
data4 = [17, 9, 58, 64, 21, 86, 48, 16, 35, 58, 10]
data5 = [32, 25, 49, 40, 13, 55, 60, 26, 57, 58, 13]
data6 = [47, 34, 55, 23, 9, 50, 77, 35, 55, 18, 22]
data7 = [53, 30, 38, 19, 8, 25, 81, 41, 47, 30, 40]
data8 = [49, 66, 36, 9, 6, 10, 48, 59, 48, 26, 54]
data9 = [69, 89, 24, 8, 3, 8, 23, 59, 53, 8, 58]
data10 = [71, 64, 9, 7, 5, 5, 18, 38, 27, 7, 34]
data11 = [51, 75, 4, 4, 6, 2, 2, 44, 19, 3, 35]
color_set = ('blue', 'tomato', 'bisque', 'springgreen', 'thistle', 'pink', 'skyblue', 'greenyellow', 'chocolate', 'khaki', 'turquoise' )

# %%
plt.figure(1)
plt.pie(data1, autopct="%0.1f%%", colors=color_set)
plt.axis('equal')
plt.legend(categories, bbox_to_anchor=(1,0), loc="best",bbox_transform=plt.gcf().transFigure)
plt.title("First Place")
# Out:
# Text(0.5, 1.0, 'First Place')

# %%
plt.figure(2)
plt.pie(data2, autopct="%0.1f%%", colors=color_set)
plt.axis('equal')
plt.legend(categories, bbox_to_anchor=(1,0), loc="best",bbox_transform=plt.gcf().transFigure)
plt.title("Second Place")
# Out:
# Text(0.5, 1.0, 'Second Place')

# %%
plt.figure(3)
plt.pie(data3, autopct="%0.1f%%", colors=color_set)
plt.axis('equal')
plt.legend(categories, bbox_to_anchor=(1,0), loc="best",bbox_transform=plt.gcf().transFigure)
plt.title("Third Place")
# Out:
# Text(0.5, 1.0, 'Third Place')

# %%
plt.figure(4)
plt.pie(data4, autopct="%0.1f%%", colors=color_set)
plt.axis('equal')
plt.legend(categories, bbox_to_anchor=(1,0), loc="best",bbox_transform=plt.gcf().transFigure)
plt.title("Fourth Place")
# Out:
# Text(0.5, 1.0, 'Fourth Place')

# %%
plt.figure(5)
plt.pie(data5, autopct="%0.1f%%", colors=color_set)
plt.axis('equal')
plt.legend(categories, bbox_to_anchor=(1,0), loc="best",bbox_transform=plt.gcf().transFigure)
plt.title("Fifth Place")
# Out:
# Text(0.5, 1.0, 'Fifth Place')

# %%
plt.figure(6)
plt.pie(data6, autopct="%0.1f%%", colors=color_set)
plt.axis('equal')
plt.legend(categories, bbox_to_anchor=(1,0), loc="best",bbox_transform=plt.gcf().transFigure)
plt.title("Sixth Place")
# Out:
# Text(0.5, 1.0, 'Sixth Place')

# %%
plt.figure(7)
plt.pie(data7, autopct="%0.1f%%", colors=color_set)
plt.axis('equal')
plt.legend(categories, bbox_to_anchor=(1,0), loc="best",bbox_transform=plt.gcf().transFigure)
plt.title("Seventh Place")
# Out:
# Text(0.5, 1.0, 'Seventh Place')

# %%
plt.figure(8)
plt.pie(data8, autopct="%0.1f%%", colors=color_set)
plt.axis('equal')
plt.legend(categories, bbox_to_anchor=(1,0), loc="best",bbox_transform=plt.gcf().transFigure)
plt.title("Eighth Place")
# Out:
# Text(0.5, 1.0, 'Eighth Place')

# %%
plt.figure(9)
plt.pie(data9, autopct="%0.1f%%", colors=color_set)
plt.axis('equal')
plt.legend(categories, bbox_to_anchor=(1,0), loc="best",bbox_transform=plt.gcf().transFigure)
plt.title("Ninth Place")
# Out:
# Text(0.5, 1.0, 'Ninth Place')

# %%
plt.figure(10)
plt.pie(data10, autopct="%0.1f%%", colors=color_set)
plt.axis('equal')
plt.legend(categories, bbox_to_anchor=(1,0), loc="best",bbox_transform=plt.gcf().transFigure)
plt.title("Tenth Place")
# Out:
# Text(0.5, 1.0, 'Tenth Place')

# %%
plt.figure(11)
plt.pie(data11, autopct="%0.1f%%", colors=color_set)
plt.axis('equal')
plt.legend(categories, bbox_to_anchor=(1,0), loc="best",bbox_transform=plt.gcf().transFigure)
plt.title("Eleventh Place")
# Out:
# Text(0.5, 1.0, 'Eleventh Place')
